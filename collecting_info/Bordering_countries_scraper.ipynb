# %%
import requests
from bs4 import BeautifulSoup
import time

url = "https://en.wikipedia.org/wiki/List_of_countries_and_territories_by_number_of_land_borders"

headers = {
    "User-Agent": "StudentResearchBot/1.0 (jochem.van.der.geest.3@student.rug.nl)"
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

print(soup.prettify())

time.sleep(2)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientpref-day vector-sticky-header-enabled wp25eastereggs-enable-clientpref-1 vector-toc-available skin-theme-clientpref-thumb-standard" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of countries and territories by number of land borders - Wikipedia
#   </title>
#   <script>
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/List_of_countries_and_territories_by_number_of_land_borders"

headers = {
    "User-Agent": "StudentResearchBot/1.0 (jochem.van.der.geest.3@student.rug.nl)"
}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

table = soup.find("table", class_="wikitable")


def clean(cell):
    # remove sup references
    for sup in cell.find_all("sup"):
        sup.decompose()
    # replace <br> with semicolon + space
    for br in cell.find_all("br"):
        br.replace_with("; ")
    text = cell.get_text()
    # normalize NBSP to space
    text = text.replace("\xa0", " ")
    
    # Now split neighbors by ';'
    neighbors_raw = [n.strip() for n in text.split(";") if n.strip()]
    
    # Optional: further clean each neighbor, ensure space formatting
    neighbors_clean = []
    for n in neighbors_raw:
        # collapse multiple spaces
        n2 = re.sub(r"\s+", " ", n).strip()
        neighbors_clean.append(n2)
        
    # join back with '; ' if you want one string,
    # or return list if you want structured data
    return "; ".join(neighbors_clean)

rows = table.find_all("tr")
cols_idx = (0, 1, 4, 5)  # columns we want

# Header
header_cells = rows[0].find_all(["th","td"])
header = [clean(header_cells[i]) if i < len(header_cells) else "" for i in cols_idx]
table_data = [header]


# Data rows
for r in rows[1:]:
    cols = r.find_all("td")
    if len(cols) >= 6:
        table_data.append([clean(cols[i]) for i in cols_idx])

# Print clean results
for r in table_data:
    print(r)
# Out:
# ['Country or territory (Territories without full sovereignty in italics)', 'Total length of land borders', 'Land border neighbours; and border length (Territories without full sovereignty in italics); (#) = No. of distinct land boundaries with that country or territory', '']
# ['Afghanistan', '5,529', '6', 'Iran: 935 km (581 mi); Pakistan: 2,670 km (1,660 mi); Tajikistan: 1,206 km (749 mi); Turkmenistan: 744 km (462 mi); Uzbekistan: 144 km (89 mi); China: 106 km (66 mi)']
# ['Albania', '720', '4', 'Greece: 282 km (175 mi); Kosovo: 112 km (70 mi); North Macedonia: 151 km (94 mi); Montenegro: 172 km (107 mi)']
# ['Algeria', '6,470', '7', 'Libya: 982 km (610 mi); Mali: 1,376 km (855 mi); Mauritania: 463 km (288 mi); Morocco: 1,559 km (969 mi); Niger: 956 km (594 mi); Tunisia: 1,010 km (630 mi); Western Sahara: 42 km (26 mi)']
# ['Andorra', '120', '2', 'France: 56.6 km (35.2 mi); Spain: 63.7 km (39.6 mi)']
# ...
